# %% [markdown]
# # Imports

# %%
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# # Utility Functions

# %%
def plot_steps_per_episode(steps_per_episode):
    plt.plot(steps_per_episode)
    plt.xlabel('Episode')
    plt.ylabel('Steps')
    plt.title('Steps per episode')
    plt.axhline(y=100, color='red', linestyle='--')
    for i in range(0, len(steps_per_episode)+1, 10000):
        plt.axvline(x=i, color='grey', linestyle='--')
    plt.show()

def extract_policy(q_table):
    # Take the action with the highest Q-value for each state
    return np.argmax(q_table, axis=1)

def plot_policy(policy, grid_size=(4, 4)):
    # Reshape the policy to match the environment's grid layout
    policy_grid = policy.reshape(grid_size)
    # Create a heatmap
    plt.figure(figsize=(8, 8))
    sns.heatmap(policy_grid, annot=True, cmap="YlGnBu", cbar=False, square=True)
    plt.title('Policy Heatmap (Best Action per State)')
    plt.show()

def check_success_condition(steps_per_episode,consecutive_episodes=5000,threshold=100):
    # Check if the agent was able to achieve X steps for 5000 consecutive episodes
    steps_per_episode = np.array(steps_per_episode)
    for i in range(len(steps_per_episode) - consecutive_episodes):
        if all(steps_per_episode[i:i+consecutive_episodes] >= threshold):
            return True
    return False

def train_agent(env, alpha, gamma, epsilon_decay, num_episodes=6000):
    q_table = np.zeros([env.observation_space.n, env.action_space.n])
    steps_per_episode = []

    for episode in range(num_episodes):
        state = env.reset()[0]
        done = False
        steps = 0
        epsilon = 1.0  # Reset epsilon at the start of each episode

        while not done:
            if np.random.uniform(0, 1) < epsilon:
                action = env.action_space.sample()  # Explore
            else:
                action = np.argmax(q_table[state])  # Exploit

            next_state, reward, done, truncated,_ = env.step(action)
            old_value = q_table[state, action]
            next_max = np.max(q_table[next_state])

            new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_max)
            q_table[state, action] = new_value

            state = next_state
            steps += 1
            epsilon = max(epsilon - epsilon_decay, 0)  # Decaying epsilon

        print(f"Episode {episode} finished after {steps} steps")
        steps_per_episode.append(steps)
        is_success = check_success_condition(steps_per_episode)
    avg_steps = np.mean(steps_per_episode[-100:])  # Average steps of the last 100 episodes
    return avg_steps, q_table, steps_per_episode, is_success

def hyperparameter_search():
    results_dict = {
        'alpha': [],
        'gamma': [],
        'epsilon_decay': [],
        'avg_steps': [],
        'success': []
    }
    env = gym.make('FrozenLake-v1')
    learning_rates = np.linspace(0.1, 1, 10)
    discount_factors = np.linspace(0.1, 1, 10)
    epsilon_decays = np.linspace(0.000001, 0.001, 10)
    best_params = {}
    min_steps = float('inf')

    for alpha in learning_rates:
        for gamma in discount_factors:
            for decay in epsilon_decays:
                avg_steps, q_table ,steps_per_episode,is_success = train_agent(env, alpha, gamma, decay)
                print(f"Alpha: {alpha}, Gamma: {gamma}, Decay: {decay}, Avg Steps: {avg_steps} Success: {is_success}")

                results_dict['alpha'].append(alpha)
                results_dict['gamma'].append(gamma)
                results_dict['epsilon_decay'].append(decay)
                results_dict['avg_steps'].append(avg_steps)
                results_dict['success'].append(is_success)

                if avg_steps < min_steps:
                    min_steps = avg_steps
                    best_params = {'alpha': alpha, 'gamma': gamma, 'epsilon_decay': decay}

    return best_params, min_steps , pd.DataFrame(results_dict)

# %%
best_hyperparameters, best_performance, results_df = hyperparameter_search()
print("Best Hyperparameters:", best_hyperparameters)
print("Best Average Steps to Goal:", best_performance)
# Out:
# Episode 0 finished after 4 steps
# Episode 1 finished after 6 steps
# Episode 2 finished after 12 steps
# Episode 3 finished after 3 steps
# Episode 4 finished after 3 steps
# Episode 5 finished after 9 steps
# Episode 6 finished after 6 steps
# Episode 7 finished after 10 steps
# Episode 8 finished after 10 steps
# Episode 9 finished after 3 steps
# Episode 10 finished after 7 steps
# Episode 11 finished after 8 steps
# Episode 12 finished after 9 steps
# Episode 13 finished after 18 steps
# Episode 14 finished after 14 steps
# Episode 15 finished after 2 steps
# Episode 16 finished after 7 steps
# Episode 17 finished after 7 steps
# Episode 18 finished after 4 steps
# Episode 19 finished after 10 steps
# Episode 20 finished after 6 steps
# Episode 21 finished after 2 steps
# Episode 22 finished after 4 steps
# Episode 23 finished after 3 steps
# Episode 24 finished after 4 steps
# Episode 25 finished after 7 steps
# Episode 26 finished after 3 steps
# Episode 27 finished after 6 steps
# Episode 28 finished after 8 steps
# Episode 29 finished after 4 steps
# Episode 30 finished after 3 steps
# Episode 31 finished after 4 steps
# Episode 32 finished after 7 steps
# Episode 33 finished after 2 steps
# Episode 34 finished after 15 steps
# Episode 35 finished after 8 steps
# Episode 36 finished after 11 steps
# Episode 37 finished after 6 steps
# Episode 38 finished after 7 steps
# Episode 39 finished after 15 steps
# Episode 40 finished after 9 steps
# Episode 41 finished after 4 steps
# Episode 42 finished after 2 steps
# Episode 43 finished after 5 steps
# Episode 44 finished after 6 steps
# Episode 45 finished after 2 steps
# Episode 46 finished after 10 steps
# Episode 47 finished after 6 steps
# Episode 48 finished after 8 steps
# Episode 49 finished after 15 steps
# Episode 50 finished after 13 steps
# Episode 51 finished after 14 steps
# Episode 52 finished after 8 steps
# Episode 53 finished after 16 steps
# Episode 54 finished after 6 steps
# Episode 55 finished after 32 steps
# Episode 56 finished after 2 steps
# Episode 57 finished after 2 steps
# Episode 58 finished after 9 steps
# Episode 59 finished after 15 steps
# Episode 60 finished after 4 steps
# Episode 61 finished after 5 steps
# Episode 62 finished after 13 steps
# Episode 63 finished after 10 steps
# Episode 64 finished after 7 steps
# Episode 65 finished after 19 steps
# Episode 66 finished after 9 steps
# Episode 67 finished after 12 steps
# Episode 68 finished after 5 steps
# Episode 69 finished after 4 steps
# Episode 70 finished after 17 steps
# Episode 71 finished after 20 steps
# Episode 72 finished after 25 steps
# Episode 73 finished after 14 steps
# Episode 74 finished after 13 steps
# Episode 75 finished after 5 steps
# Episode 76 finished after 14 steps
# Episode 77 finished after 4 steps
# Episode 78 finished after 2 steps
# Episode 79 finished after 12 steps
# Episode 80 finished after 4 steps
# Episode 81 finished after 3 steps
# Episode 82 finished after 3 steps
# Episode 83 finished after 11 steps
# Episode 84 finished after 3 steps
# Episode 85 finished after 11 steps
# Episode 86 finished after 4 steps
# Episode 87 finished after 24 steps
# Episode 88 finished after 5 steps
# Episode 89 finished after 4 steps
# Episode 90 finished after 3 steps
# Episode 91 finished after 10 steps
# Episode 92 finished after 2 steps
# Episode 93 finished after 2 steps
# Episode 94 finished after 2 steps
# Episode 95 finished after 8 steps
# Episode 96 finished after 5 steps
# Episode 97 finished after 17 steps
# Episode 98 finished after 5 steps
# Episode 99 finished after 4 steps
# Episode 100 finished after 9 steps
# Episode 101 finished after 3 steps
# Episode 102 finished after 6 steps
# Episode 103 finished after 2 steps
# Episode 104 finished after 5 steps
# Episode 105 finished after 8 steps
# Episode 106 finished after 4 steps
# Episode 107 finished after 3 steps
# Episode 108 finished after 3 steps
# Episode 109 finished after 7 steps
# Episode 110 finished after 6 steps
# Episode 111 finished after 12 steps
# Episode 112 finished after 14 steps
# Episode 113 finished after 5 steps
# Episode 114 finished after 17 steps
# Episode 115 finished after 9 steps
# Episode 116 finished after 6 steps
# Episode 117 finished after 9 steps
# Episode 118 finished after 5 steps
# Episode 119 finished after 4 steps
# Episode 120 finished after 9 steps
# Episode 121 finished after 10 steps
# Episode 122 finished after 7 steps
# Episode 123 finished after 7 steps
# Episode 124 finished after 19 steps
# Episode 125 finished after 12 steps
# Episode 126 finished after 2 steps
# Episode 127 finished after 19 steps
# Episode 128 finished after 3 steps
# Episode 129 finished after 5 steps
# Episode 130 finished after 3 steps
# Episode 131 finished after 5 steps
# Episode 132 finished after 2 steps
# Episode 133 finished after 11 steps
# Episode 134 finished after 3 steps
# Episode 135 finished after 6 steps
# Episode 136 finished after 3 steps
# Episode 137 finished after 6 steps
# Episode 138 finished after 4 steps
# Episode 139 finished after 8 steps
# Episode 140 finished after 4 steps
# Episode 141 finished after 3 steps
# Episode 142 finished after 6 steps
# Episode 143 finished after 7 steps
# Episode 144 finished after 9 steps
# Episode 145 finished after 8 steps
# Episode 146 finished after 3 steps
# Episode 147 finished after 10 steps
# Episode 148 finished after 7 steps
# Episode 149 finished after 8 steps
# Episode 150 finished after 15 steps
# Episode 151 finished after 4 steps
# Episode 152 finished after 8 steps
# Episode 153 finished after 5 steps
# Episode 154 finished after 10 steps
# Episode 155 finished after 2 steps
# Episode 156 finished after 18 steps
# Episode 157 finished after 7 steps
# Episode 158 finished after 5 steps
# Episode 159 finished after 6 steps
# Episode 160 finished after 6 steps
# Episode 161 finished after 2 steps
# Episode 162 finished after 8 steps
# Episode 163 finished after 4 steps
# Episode 164 finished after 4 steps
# Episode 165 finished after 5 steps
# Episode 166 finished after 17 steps
# Episode 167 finished after 16 steps
# Episode 168 finished after 6 steps
# Episode 169 finished after 2 steps
# Episode 170 finished after 6 steps
# Episode 171 finished after 2 steps
# Episode 172 finished after 9 steps
# Episode 173 finished after 9 steps
# Episode 174 finished after 9 steps
# Episode 175 finished after 11 steps
# Episode 176 finished after 7 steps
# Episode 177 finished after 4 steps
# Episode 178 finished after 11 steps
# Episode 179 finished after 2 steps
# Episode 180 finished after 7 steps
# Episode 181 finished after 3 steps
# Episode 182 finished after 17 steps
# Episode 183 finished after 13 steps
# Episode 184 finished after 7 steps
# Episode 185 finished after 14 steps
# Episode 186 finished after 17 steps
# Episode 187 finished after 2 steps
# Episode 188 finished after 2 steps
# Episode 189 finished after 22 steps
# Episode 190 finished after 4 steps
# Episode 191 finished after 6 steps
# Episode 192 finished after 3 steps
# Episode 193 finished after 6 steps
# Episode 194 finished after 5 steps
# Episode 195 finished after 15 steps
# Episode 196 finished after 18 steps
# Episode 197 finished after 8 steps
# Episode 198 finished after 7 steps
# Episode 199 finished after 15 steps
# Episode 200 finished after 10 steps
# Episode 201 finished after 6 steps
# Episode 202 finished after 15 steps
# Episode 203 finished after 8 steps
# Episode 204 finished after 7 steps
# Episode 205 finished after 3 steps
# Episode 206 finished after 5 steps
# Episode 207 finished after 11 steps
# Episode 208 finished after 8 steps
# Episode 209 finished after 4 steps
# Episode 210 finished after 9 steps
# Episode 211 finished after 6 steps
# Episode 212 finished after 6 steps
# Episode 213 finished after 13 steps
# Episode 214 finished after 8 steps
# Episode 215 finished after 2 steps
# Episode 216 finished after 15 steps
# Episode 217 finished after 5 steps
# Episode 218 finished after 3 steps
# Episode 219 finished after 2 steps
# Episode 220 finished after 9 steps
# Episode 221 finished after 4 steps
# Episode 222 finished after 2 steps
# Episode 223 finished after 12 steps
# Episode 224 finished after 2 steps
# Episode 225 finished after 26 steps
# Episode 226 finished after 11 steps
# Episode 227 finished after 4 steps
# Episode 228 finished after 10 steps
# Episode 229 finished after 10 steps
# Episode 230 finished after 4 steps
# Episode 231 finished after 7 steps
# Episode 232 finished after 10 steps
# Episode 233 finished after 19 steps
# Episode 234 finished after 6 steps
# Episode 235 finished after 15 steps
# Episode 236 finished after 9 steps
# Episode 237 finished after 5 steps
# Episode 238 finished after 22 steps
# Episode 239 finished after 4 steps
# Episode 240 finished after 8 steps
# Episode 241 finished after 8 steps
# Episode 242 finished after 8 steps
# Episode 243 finished after 3 steps
# Episode 244 finished after 18 steps
# Episode 245 finished after 5 steps
# Episode 246 finished after 4 steps
# Episode 247 finished after 13 steps
# Episode 248 finished after 2 steps
# Episode 249 finished after 16 steps
# Episode 250 finished after 13 steps
# Episode 251 finished after 14 steps
# Episode 252 finished after 11 steps
# Episode 253 finished after 9 steps
# Episode 254 finished after 4 steps
# Episode 255 finished after 3 steps
# Episode 256 finished after 5 steps
# Episode 257 finished after 2 steps
# Episode 258 finished after 10 steps
# Episode 259 finished after 4 steps
# Episode 260 finished after 8 steps
# Episode 261 finished after 5 steps
# Episode 262 finished after 6 steps
# Episode 263 finished after 3 steps
# Episode 264 finished after 6 steps
# Episode 265 finished after 13 steps
# Episode 266 finished after 2 steps
# Episode 267 finished after 12 steps
# Episode 268 finished after 3 steps
# Episode 269 finished after 2 steps
# Episode 270 finished after 5 steps
# Episode 271 finished after 13 steps
# Episode 272 finished after 2 steps
# Episode 273 finished after 2 steps
# Episode 274 finished after 29 steps
# Episode 275 finished after 5 steps
# Episode 276 finished after 6 steps
# Episode 277 finished after 5 steps
# Episode 278 finished after 4 steps
# Episode 279 finished after 7 steps
# Episode 280 finished after 12 steps
# Episode 281 finished after 2 steps
# Episode 282 finished after 16 steps
# Episode 283 finished after 24 steps
# Episode 284 finished after 3 steps
# Episode 285 finished after 4 steps
# Episode 286 finished after 5 steps
# Episode 287 finished after 24 steps
# Episode 288 finished after 2 steps
# Episode 289 finished after 4 steps
# Episode 290 finished after 8 steps
# Episode 291 finished after 11 steps
# Episode 292 finished after 12 steps
# Episode 293 finished after 3 steps
# Episode 294 finished after 4 steps
# Episode 295 finished after 3 steps
# Episode 296 finished after 16 steps
# Episode 297 finished after 3 steps
# Episode 298 finished after 9 steps
# Episode 299 finished after 28 steps
# Episode 300 finished after 8 steps
# Episode 301 finished after 3 steps
# Episode 302 finished after 7 steps
# Episode 303 finished after 6 steps
# Episode 304 finished after 3 steps
# Episode 305 finished after 5 steps
# Episode 306 finished after 6 steps
# Episode 307 finished after 29 steps
# Episode 308 finished after 6 steps
# Episode 309 finished after 6 steps
# Episode 310 finished after 4 steps
# Episode 311 finished after 8 steps
# Episode 312 finished after 9 steps
# Episode 313 finished after 18 steps
# Episode 314 finished after 8 steps
# Episode 315 finished after 6 steps
# Episode 316 finished after 8 steps
# Episode 317 finished after 8 steps
# Episode 318 finished after 24 steps
# Episode 319 finished after 5 steps
# Episode 320 finished after 3 steps
# Episode 321 finished after 5 steps
# Episode 322 finished after 3 steps
# Episode 323 finished after 27 steps
# Episode 324 finished after 9 steps
# Episode 325 finished after 7 steps
# Episode 326 finished after 2 steps
# Episode 327 finished after 9 steps
# Episode 328 finished after 6 steps
# Episode 329 finished after 4 steps
# Episode 330 finished after 6 steps
# Episode 331 finished after 9 steps
# Episode 332 finished after 9 steps
# Episode 333 finished after 17 steps
# Episode 334 finished after 5 steps
# Episode 335 finished after 3 steps
# Episode 336 finished after 6 steps
# Episode 337 finished after 5 steps
# Episode 338 finished after 6 steps
# Episode 339 finished after 5 steps
# Episode 340 finished after 8 steps
# Episode 341 finished after 3 steps
# Episode 342 finished after 45 steps
# Episode 343 finished after 3 steps
# Episode 344 finished after 4 steps
# Episode 345 finished after 5 steps
# Episode 346 finished after 3 steps
# Episode 347 finished after 7 steps
# Episode 348 finished after 6 steps
# Episode 349 finished after 4 steps
# Episode 350 finished after 11 steps
# Episode 351 finished after 6 steps
# Episode 352 finished after 4 steps
# Episode 353 finished after 4 steps
# Episode 354 finished after 7 steps
# Episode 355 finished after 2 steps
# Episode 356 finished after 16 steps
# Episode 357 finished after 4 steps
# Episode 358 finished after 2 steps
# Episode 359 finished after 9 steps
# Episode 360 finished after 5 steps
# Episode 361 finished after 6 steps
# Episode 362 finished after 2 steps
# Episode 363 finished after 2 steps
# Episode 364 finished after 27 steps
# Episode 365 finished after 5 steps
# Episode 366 finished after 4 steps
# Episode 367 finished after 11 steps
# Episode 368 finished after 3 steps
# Episode 369 finished after 2 steps
# Episode 370 finished after 9 steps
# Episode 371 finished after 15 steps
# Episode 372 finished after 2 steps
# Episode 373 finished after 2 steps
# Episode 374 finished after 2 steps
# Episode 375 finished after 6 steps
# Episode 376 finished after 2 steps
# Episode 377 finished after 7 steps
# Episode 378 finished after 6 steps
# Episode 379 finished after 22 steps
# Episode 380 finished after 2 steps
# Episode 381 finished after 10 steps
# Episode 382 finished after 8 steps
# Episode 383 finished after 6 steps
# Episode 384 finished after 10 steps
# Episode 385 finished after 4 steps
# Episode 386 finished after 9 steps
# Episode 387 finished after 16 steps
# Episode 388 finished after 7 steps
# Episode 389 finished after 21 steps
# Episode 390 finished after 5 steps
# Episode 391 finished after 7 steps
# Episode 392 finished after 11 steps
# Episode 393 finished after 11 steps
# Episode 394 finished after 11 steps
# Episode 395 finished after 7 steps
# Episode 396 finished after 2 steps
# Episode 397 finished after 12 steps
# Episode 398 finished after 9 steps
# Episode 399 finished after 2 steps
# Episode 400 finished after 2 steps
# Episode 401 finished after 8 steps
# Episode 402 finished after 5 steps
# Episode 403 finished after 8 steps
# Episode 404 finished after 13 steps
# Episode 405 finished after 9 steps
# Episode 406 finished after 2 steps
# Episode 407 finished after 12 steps
# Episode 408 finished after 8 steps
# Episode 409 finished after 7 steps
# Episode 410 finished after 2 steps
# Episode 411 finished after 3 steps
# Episode 412 finished after 10 steps
# Episode 413 finished after 4 steps
# Episode 414 finished after 13 steps
# Episode 415 finished after 7 steps
# Episode 416 finished after 6 steps
# Episode 417 finished after 6 steps
# Episode 418 finished after 10 steps
# Episode 419 finished after 8 steps
# Episode 420 finished after 7 steps
# Episode 421 finished after 30 steps
# Episode 422 finished after 6 steps
# Episode 423 finished after 7 steps
# Episode 424 finished after 3 steps
# Episode 425 finished after 3 steps
# Episode 426 finished after 8 steps
# Episode 427 finished after 10 steps
# Episode 428 finished after 5 steps
# Episode 429 finished after 5 steps
# Episode 430 finished after 7 steps
# Episode 431 finished after 3 steps
# Episode 432 finished after 4 steps
# Episode 433 finished after 9 steps
# Episode 434 finished after 3 steps
# Episode 435 finished after 12 steps
# Episode 436 finished after 3 steps
# Episode 437 finished after 6 steps
# Episode 438 finished after 3 steps
# Episode 439 finished after 6 steps
# Episode 440 finished after 4 steps
# Episode 441 finished after 25 steps
# Episode 442 finished after 11 steps
# Episode 443 finished after 12 steps
# Episode 444 finished after 14 steps
# Episode 445 finished after 4 steps
# Episode 446 finished after 13 steps
# Episode 447 finished after 8 steps
# Episode 448 finished after 4 steps
# Episode 449 finished after 2 steps
# Episode 450 finished after 2 steps
# Episode 451 finished after 8 steps
# Episode 452 finished after 6 steps
# Episode 453 finished after 20 steps
# Episode 454 finished after 2 steps
# Episode 455 finished after 35 steps
# Episode 456 finished after 5 steps
# Episode 457 finished after 13 steps
# Episode 458 finished after 5 steps
# Episode 459 finished after 16 steps
# Episode 460 finished after 5 steps
# Episode 461 finished after 3 steps
# Episode 462 finished after 3 steps
# Episode 463 finished after 7 steps
# Episode 464 finished after 3 steps
# Episode 465 finished after 7 steps
# Episode 466 finished after 11 steps
# Episode 467 finished after 2 steps
# Episode 468 finished after 16 steps
# Episode 469 finished after 6 steps
# Episode 470 finished after 2 steps
# Episode 471 finished after 3 steps
# Episode 472 finished after 10 steps
# Episode 473 finished after 10 steps
# Episode 474 finished after 6 steps
# Episode 475 finished after 6 steps
# Episode 476 finished after 4 steps
# Episode 477 finished after 10 steps
# Episode 478 finished after 7 steps
# Episode 479 finished after 9 steps
# Episode 480 finished after 21 steps
# Episode 481 finished after 3 steps
# Episode 482 finished after 10 steps
# Episode 483 finished after 7 steps
# Episode 484 finished after 4 steps
# Episode 485 finished after 5 steps
# Episode 486 finished after 2 steps
# Episode 487 finished after 3 steps
# Episode 488 finished after 10 steps
# Episode 489 finished after 3 steps
# Episode 490 finished after 10 steps
# Episode 491 finished after 5 steps
# Episode 492 finished after 19 steps
# Episode 493 finished after 4 steps
# Episode 494 finished after 7 steps
# Episode 495 finished after 6 steps
# Episode 496 finished after 2 steps
# Episode 497 finished after 8 steps
# Episode 498 finished after 5 steps
# Episode 499 finished after 4 steps
# Episode 500 finished after 13 steps
# Episode 501 finished after 3 steps
# Episode 502 finished after 10 steps
# Episode 503 finished after 9 steps
# Episode 504 finished after 12 steps
# Episode 505 finished after 3 steps
# Episode 506 finished after 2 steps
# Episode 507 finished after 5 steps
# Episode 508 finished after 4 steps
# Episode 509 finished after 9 steps
# Episode 510 finished after 5 steps
# Episode 511 finished after 17 steps
# Episode 512 finished after 9 steps
# Episode 513 finished after 5 steps
# Episode 514 finished after 4 steps
# Episode 515 finished after 15 steps
# Episode 516 finished after 6 steps
# Episode 517 finished after 2 steps
# Episode 518 finished after 3 steps
# Episode 519 finished after 8 steps
# Episode 520 finished after 7 steps
# Episode 521 finished after 6 steps
# Episode 522 finished after 5 steps
# Episode 523 finished after 16 steps
# Episode 524 finished after 16 steps
# Episode 525 finished after 4 steps
# Episode 526 finished after 2 steps
# Episode 527 finished after 11 steps
# Episode 528 finished after 13 steps
# Episode 529 finished after 3 steps
# Episode 530 finished after 4 steps
# Episode 531 finished after 6 steps
# Episode 532 finished after 8 steps
# Episode 533 finished after 13 steps
# Episode 534 finished after 4 steps
# Episode 535 finished after 10 steps
# Episode 536 finished after 6 steps
# Episode 537 finished after 17 steps
# Episode 538 finished after 4 steps
# Episode 539 finished after 10 steps
# Episode 540 finished after 6 steps
# Episode 541 finished after 6 steps
# Episode 542 finished after 8 steps
# Episode 543 finished after 4 steps
# Episode 544 finished after 4 steps
# Episode 545 finished after 4 steps
# Episode 546 finished after 4 steps
# Episode 547 finished after 5 steps
# Episode 548 finished after 6 steps
# Episode 549 finished after 7 steps
# Episode 550 finished after 3 steps
# Episode 551 finished after 7 steps
# Episode 552 finished after 3 steps
# Episode 553 finished after 8 steps
# Episode 554 finished after 3 steps
# Episode 555 finished after 9 steps
# Episode 556 finished after 8 steps
# Episode 557 finished after 8 steps
# Episode 558 finished after 8 steps
# Episode 559 finished after 11 steps
# Episode 560 finished after 5 steps
# Episode 561 finished after 6 steps
# Episode 562 finished after 8 steps
# Episode 563 finished after 13 steps
# Episode 564 finished after 11 steps
# Episode 565 finished after 6 steps
# Episode 566 finished after 3 steps
# Episode 567 finished after 2 steps
# Episode 568 finished after 11 steps
# Episode 569 finished after 4 steps
# Episode 570 finished after 7 steps
# Episode 571 finished after 28 steps
# Episode 572 finished after 9 steps
# Episode 573 finished after 3 steps
# Episode 574 finished after 2 steps
# Episode 575 finished after 20 steps
# Episode 576 finished after 20 steps
# Episode 577 finished after 2 steps
# Episode 578 finished after 5 steps
# Episode 579 finished after 5 steps
# Episode 580 finished after 3 steps
# Episode 581 finished after 5 steps
# Episode 582 finished after 8 steps
# Episode 583 finished after 4 steps
# Episode 584 finished after 6 steps
# Episode 585 finished after 2 steps
# Episode 586 finished after 8 steps
# Episode 587 finished after 8 steps
# Episode 588 finished after 10 steps
# Episode 589 finished after 7 steps
# Episode 590 finished after 4 steps
# Episode 591 finished after 12 steps
# Episode 592 finished after 4 steps
# Episode 593 finished after 5 steps
# Episode 594 finished after 8 steps
# Episode 595 finished after 7 steps
# Episode 596 finished after 6 steps
# Episode 597 finished after 6 steps
# Episode 598 finished after 6 steps
# Episode 599 finished after 5 steps
# Episode 600 finished after 16 steps
# Episode 601 finished after 4 steps
# Episode 602 finished after 14 steps
# Episode 603 finished after 10 steps
# Episode 604 finished after 3 steps
# Episode 605 finished after 6 steps
# Episode 606 finished after 3 steps
# Episode 607 finished after 5 steps
# Episode 608 finished after 3 steps
# Episode 609 finished after 2 steps
# Episode 610 finished after 11 steps
# Episode 611 finished after 9 steps
# Episode 612 finished after 4 steps
# Episode 613 finished after 5 steps
# Episode 614 finished after 4 steps
# Episode 615 finished after 9 steps
# Episode 616 finished after 2 steps
# Episode 617 finished after 7 steps
# Episode 618 finished after 4 steps
# Episode 619 finished after 2 steps
# Episode 620 finished after 4 steps
# Episode 621 finished after 2 steps
# Episode 622 finished after 15 steps
# Episode 623 finished after 2 steps
# Episode 624 finished after 3 steps
# Episode 625 finished after 2 steps
# Episode 626 finished after 6 steps
# Episode 627 finished after 4 steps
# Episode 628 finished after 2 steps
# Episode 629 finished after 5 steps
# Episode 630 finished after 3 steps
# Episode 631 finished after 3 steps
# Episode 632 finished after 27 steps
# Episode 633 finished after 7 steps
# Episode 634 finished after 7 steps
# Episode 635 finished after 9 steps
# Episode 636 finished after 3 steps
# Episode 637 finished after 2 steps
# Episode 638 finished after 2 steps
# Episode 639 finished after 6 steps
# Episode 640 finished after 5 steps
# Episode 641 finished after 2 steps
# Episode 642 finished after 2 steps
# Episode 643 finished after 2 steps
# Episode 644 finished after 9 steps
# Episode 645 finished after 22 steps
# Episode 646 finished after 11 steps
# Episode 647 finished after 3 steps
# Episode 648 finished after 9 steps
# Episode 649 finished after 4 steps
# Episode 650 finished after 11 steps
# Episode 651 finished after 4 steps
# Episode 652 finished after 9 steps
# Episode 653 finished after 28 steps
# Episode 654 finished after 3 steps
# Episode 655 finished after 10 steps
# Episode 656 finished after 4 steps
# Episode 657 finished after 3 steps
# Episode 658 finished after 5 steps
# Episode 659 finished after 4 steps
# Episode 660 finished after 11 steps
# Episode 661 finished after 6 steps
# Episode 662 finished after 9 steps
# Episode 663 finished after 8 steps
# Episode 664 finished after 3 steps
# Episode 665 finished after 7 steps
# Episode 666 finished after 6 steps
# Episode 667 finished after 4 steps
# Episode 668 finished after 2 steps
# Episode 669 finished after 10 steps
# Episode 670 finished after 18 steps
# Episode 671 finished after 5 steps
# Episode 672 finished after 3 steps
# Episode 673 finished after 2 steps
# Episode 674 finished after 13 steps
# Episode 675 finished after 19 steps
# Episode 676 finished after 3 steps
# Episode 677 finished after 22 steps
# Episode 678 finished after 19 steps
# Episode 679 finished after 15 steps
# Episode 680 finished after 6 steps
# Episode 681 finished after 2 steps
# Episode 682 finished after 7 steps
# Episode 683 finished after 6 steps
# Episode 684 finished after 4 steps
# Episode 685 finished after 9 steps
# Episode 686 finished after 9 steps
# Episode 687 finished after 16 steps
# Episode 688 finished after 4 steps
# Episode 689 finished after 10 steps
# Episode 690 finished after 5 steps
# Episode 691 finished after 11 steps
# Episode 692 finished after 13 steps
# Episode 693 finished after 12 steps
# Episode 694 finished after 2 steps
# Episode 695 finished after 20 steps
# Episode 696 finished after 6 steps
# Episode 697 finished after 6 steps
# Episode 698 finished after 4 steps
# Episode 699 finished after 9 steps
# Episode 700 finished after 7 steps
# Episode 701 finished after 3 steps
# Episode 702 finished after 5 steps
# Episode 703 finished after 4 steps
# Episode 704 finished after 15 steps
# Episode 705 finished after 5 steps
# Episode 706 finished after 28 steps
# Episode 707 finished after 8 steps
# Episode 708 finished after 2 steps
# Episode 709 finished after 11 steps
# Episode 710 finished after 5 steps
# Episode 711 finished after 10 steps
# Episode 712 finished after 16 steps
# Episode 713 finished after 6 steps
# Episode 714 finished after 9 steps
# Episode 715 finished after 4 steps
# Episode 716 finished after 7 steps
# Episode 717 finished after 7 steps
# Episode 718 finished after 12 steps
# Episode 719 finished after 3 steps
# Episode 720 finished after 6 steps
# Episode 721 finished after 19 steps
# Episode 722 finished after 15 steps
# Episode 723 finished after 11 steps
# Episode 724 finished after 3 steps
# Episode 725 finished after 23 steps
# Episode 726 finished after 6 steps
# Episode 727 finished after 15 steps
# Episode 728 finished after 2 steps
# Episode 729 finished after 4 steps
# Episode 730 finished after 10 steps
# Episode 731 finished after 4 steps
# Episode 732 finished after 2 steps
# Episode 733 finished after 4 steps
# Episode 734 finished after 6 steps
# Episode 735 finished after 14 steps
# Episode 736 finished after 18 steps
# Episode 737 finished after 6 steps
# Episode 738 finished after 2 steps
# Episode 739 finished after 4 steps
# Episode 740 finished after 2 steps
# Episode 741 finished after 2 steps
# Episode 742 finished after 2 steps
# Episode 743 finished after 8 steps
# Episode 744 finished after 11 steps
# Episode 745 finished after 12 steps
# Episode 746 finished after 14 steps
# Episode 747 finished after 7 steps
# Episode 748 finished after 4 steps
# Episode 749 finished after 2 steps
# Episode 750 finished after 2 steps
# Episode 751 finished after 11 steps
# Episode 752 finished after 13 steps
# Episode 753 finished after 2 steps
# Episode 754 finished after 2 steps
# Episode 755 finished after 7 steps
# Episode 756 finished after 6 steps
# Episode 757 finished after 8 steps
# Episode 758 finished after 11 steps
# Episode 759 finished after 12 steps
# Episode 760 finished after 7 steps
# Episode 761 finished after 10 steps
# Episode 762 finished after 8 steps
# Episode 763 finished after 3 steps
# Episode 764 finished after 5 steps
# Episode 765 finished after 9 steps
# Episode 766 finished after 5 steps
# Episode 767 finished after 7 steps
# Episode 768 finished after 10 steps
# Episode 769 finished after 9 steps
# Episode 770 finished after 21 steps
# Episode 771 finished after 2 steps
# Episode 772 finished after 5 steps
# Episode 773 finished after 10 steps
# Episode 774 finished after 3 steps
# Episode 775 finished after 8 steps
# Episode 776 finished after 6 steps
# Episode 777 finished after 2 steps
# Episode 778 finished after 10 steps
# Episode 779 finished after 4 steps
# Episode 780 finished after 4 steps
# Episode 781 finished after 9 steps
# Episode 782 finished after 4 steps
# Episode 783 finished after 6 steps
# Episode 784 finished after 3 steps
# Episode 785 finished after 2 steps
# Episode 786 finished after 14 steps
# Episode 787 finished after 13 steps
# Episode 788 finished after 7 steps
# Episode 789 finished after 14 steps
# Episode 790 finished after 6 steps
# Episode 791 finished after 17 steps
# Episode 792 finished after 3 steps
# Episode 793 finished after 10 steps
# Episode 794 finished after 9 steps
# Episode 795 finished after 9 steps
# Episode 796 finished after 6 steps
# Episode 797 finished after 12 steps
# Episode 798 finished after 2 steps
# Episode 799 finished after 7 steps
# Episode 800 finished after 2 steps
# Episode 801 finished after 4 steps
# Episode 802 finished after 6 steps
# Episode 803 finished after 2 steps
# Episode 804 finished after 9 steps
# Episode 805 finished after 5 steps
# Episode 806 finished after 10 steps
# Episode 807 finished after 8 steps
# Episode 808 finished after 4 steps
# Episode 809 finished after 6 steps
# Episode 810 finished after 7 steps
# Episode 811 finished after 6 steps
# Episode 812 finished after 12 steps
# Episode 813 finished after 2 steps
# Episode 814 finished after 6 steps
# Episode 815 finished after 7 steps
# Episode 816 finished after 14 steps
# Episode 817 finished after 8 steps
# Episode 818 finished after 6 steps
# Episode 819 finished after 8 steps
# Episode 820 finished after 2 steps
# Episode 821 finished after 2 steps
# Episode 822 finished after 20 steps
# Episode 823 finished after 4 steps
# Episode 824 finished after 16 steps
# Episode 825 finished after 3 steps
# Episode 826 finished after 25 steps
# Episode 827 finished after 4 steps
# Episode 828 finished after 3 steps
# Episode 829 finished after 5 steps
# Episode 830 finished after 7 steps
# Episode 831 finished after 3 steps
# Episode 832 finished after 4 steps
# Episode 833 finished after 17 steps
# Episode 834 finished after 2 steps
# Episode 835 finished after 8 steps
# Episode 836 finished after 16 steps
# Episode 837 finished after 4 steps
# Episode 838 finished after 4 steps
# Episode 839 finished after 5 steps
# Episode 840 finished after 6 steps
# Episode 841 finished after 4 steps
# Episode 842 finished after 6 steps
# Episode 843 finished after 3 steps
# Episode 844 finished after 12 steps
# Episode 845 finished after 5 steps
# Episode 846 finished after 6 steps
# Episode 847 finished after 19 steps
# Episode 848 finished after 21 steps
# Episode 849 finished after 11 steps
# Episode 850 finished after 8 steps
# Episode 851 finished after 4 steps
# Episode 852 finished after 9 steps
# Episode 853 finished after 15 steps
# Episode 854 finished after 7 steps
# Episode 855 finished after 4 steps
# Episode 856 finished after 5 steps
# Episode 857 finished after 4 steps
# Episode 858 finished after 4 steps
# Episode 859 finished after 2 steps
# Episode 860 finished after 7 steps
# Episode 861 finished after 4 steps
# Episode 862 finished after 13 steps
# Episode 863 finished after 14 steps
# Episode 864 finished after 6 steps
# Episode 865 finished after 8 steps
# Episode 866 finished after 10 steps
# Episode 867 finished after 12 steps
# Episode 868 finished after 25 steps
# Episode 869 finished after 3 steps
# Episode 870 finished after 3 steps
# Episode 871 finished after 2 steps
# Episode 872 finished after 12 steps
# Episode 873 finished after 19 steps
# Episode 874 finished after 11 steps
# Episode 875 finished after 3 steps
# Episode 876 finished after 4 steps
# Episode 877 finished after 10 steps
# Episode 878 finished after 2 steps
# Episode 879 finished after 10 steps
# Episode 880 finished after 7 steps
# Episode 881 finished after 8 steps
# Episode 882 finished after 3 steps
# Episode 883 finished after 15 steps
# Episode 884 finished after 13 steps
# Episode 885 finished after 7 steps
# Episode 886 finished after 7 steps
# Episode 887 finished after 4 steps
# Episode 888 finished after 14 steps
# Episode 889 finished after 14 steps
# Episode 890 finished after 15 steps
# Episode 891 finished after 3 steps
# Episode 892 finished after 7 steps
# Episode 893 finished after 9 steps
# Episode 894 finished after 6 steps
# Episode 895 finished after 7 steps
# Episode 896 finished after 4 steps
# Episode 897 finished after 4 steps
# Episode 898 finished after 7 steps
# Episode 899 finished after 2 steps
# Episode 900 finished after 5 steps
# Episode 901 finished after 4 steps
# Episode 902 finished after 5 steps
# Episode 903 finished after 8 steps
# Episode 904 finished after 19 steps
# Episode 905 finished after 3 steps
# Episode 906 finished after 4 steps
# Episode 907 finished after 2 steps
# Episode 908 finished after 8 steps
# Episode 909 finished after 4 steps
# Episode 910 finished after 3 steps
# Episode 911 finished after 13 steps
# Episode 912 finished after 4 steps
# Episode 913 finished after 5 steps
# Episode 914 finished after 9 steps
# Episode 915 finished after 2 steps
# Episode 916 finished after 6 steps
# Episode 917 finished after 7 steps
# Episode 918 finished after 11 steps
# Episode 919 finished after 3 steps
# Episode 920 finished after 24 steps
# Episode 921 finished after 3 steps
# Episode 922 finished after 9 steps
# Episode 923 finished after 10 steps
# Episode 924 finished after 6 steps
# Episode 925 finished after 8 steps
# Episode 926 finished after 2 steps
# Episode 927 finished after 5 steps
# Episode 928 finished after 3 steps
# Episode 929 finished after 4 steps
# Episode 930 finished after 5 steps
# Episode 931 finished after 4 steps
# Episode 932 finished after 4 steps
# Episode 933 finished after 3 steps
# Episode 934 finished after 6 steps
# Episode 935 finished after 16 steps
# Episode 936 finished after 4 steps
# Episode 937 finished after 16 steps
# Episode 938 finished after 4 steps
# Episode 939 finished after 9 steps
# Episode 940 finished after 3 steps
# Episode 941 finished after 2 steps
# Episode 942 finished after 2 steps
# Episode 943 finished after 5 steps
# Episode 944 finished after 7 steps
# Episode 945 finished after 11 steps
# Episode 946 finished after 3 steps
# Episode 947 finished after 3 steps
# Episode 948 finished after 16 steps
# Episode 949 finished after 6 steps
# Episode 950 finished after 9 steps
# Episode 951 finished after 4 steps
# Episode 952 finished after 8 steps
# Episode 953 finished after 35 steps
# Episode 954 finished after 8 steps
# Episode 955 finished after 9 steps
# Episode 956 finished after 3 steps
# Episode 957 finished after 10 steps
# Episode 958 finished after 5 steps
# Episode 959 finished after 12 steps
# Episode 960 finished after 2 steps
# Episode 961 finished after 4 steps
# Episode 962 finished after 23 steps
# Episode 963 finished after 6 steps
# Episode 964 finished after 11 steps
# Episode 965 finished after 2 steps
# Episode 966 finished after 12 steps
# Episode 967 finished after 5 steps
# Episode 968 finished after 6 steps
# Episode 969 finished after 4 steps
# Episode 970 finished after 15 steps
# Episode 971 finished after 12 steps
# Episode 972 finished after 5 steps
# Episode 973 finished after 2 steps
# Episode 974 finished after 7 steps
# Episode 975 finished after 2 steps
# Episode 976 finished after 7 steps
# Episode 977 finished after 9 steps
# Episode 978 finished after 7 steps
# Episode 979 finished after 14 steps
# Episode 980 finished after 3 steps
# Episode 981 finished after 18 steps
# Episode 982 finished after 2 steps
# Episode 983 finished after 5 steps
# Episode 984 finished after 9 steps
# Episode 985 finished after 22 steps
# Episode 986 finished after 5 steps
# Episode 987 finished after 3 steps
# Episode 988 finished after 10 steps
# Episode 989 finished after 11 steps
# Episode 990 finished after 2 steps
# Episode 991 finished after 9 steps
# Episode 992 finished after 5 steps
# Episode 993 finished after 13 steps
# Episode 994 finished after 4 steps
# Episode 995 finished after 3 steps
# Episode 996 finished after 13 steps
# Episode 997 finished after 29 steps
# Episode 998 finished after 2 steps
# Episode 999 finished after 6 steps
# Episode 1000 finished after 6 steps
# Episode 1001 finished after 5 steps
# Episode 1002 finished after 12 steps
# Episode 1003 finished after 3 steps
# Episode 1004 finished after 5 steps
# Episode 1005 finished after 5 steps
# Episode 1006 finished after 7 steps
# Episode 1007 finished after 11 steps
# Episode 1008 finished after 8 steps
# Episode 1009 finished after 11 steps
# Episode 1010 finished after 3 steps
# Episode 1011 finished after 6 steps
# Episode 1012 finished after 20 steps
# Episode 1013 finished after 2 steps
# Episode 1014 finished after 12 steps
# Episode 1015 finished after 3 steps
# Episode 1016 finished after 7 steps
# Episode 1017 finished after 5 steps
# Episode 1018 finished after 3 steps
# Episode 1019 finished after 9 steps
# Episode 1020 finished after 8 steps
# Episode 1021 finished after 9 steps
# Episode 1022 finished after 3 steps
# Episode 1023 finished after 9 steps
# Episode 1024 finished after 2 steps
# Episode 1025 finished after 5 steps
# Episode 1026 finished after 2 steps
# Episode 1027 finished after 6 steps
# Episode 1028 finished after 9 steps
# Episode 1029 finished after 2 steps
# Episode 1030 finished after 6 steps
# Episode 1031 finished after 9 steps
# Episode 1032 finished after 3 steps
# Episode 1033 finished after 5 steps
# Episode 1034 finished after 6 steps
# Episode 1035 finished after 3 steps
# Episode 1036 finished after 4 steps
# Episode 1037 finished after 3 steps
# Episode 1038 finished after 7 steps
# Episode 1039 finished after 2 steps
# Episode 1040 finished after 32 steps
# Episode 1041 finished after 6 steps
# Episode 1042 finished after 3 steps
# Episode 1043 finished after 4 steps
# Episode 1044 finished after 6 steps
# Episode 1045 finished after 5 steps
# Episode 1046 finished after 2 steps
# Episode 1047 finished after 3 steps
# Episode 1048 finished after 12 steps
# Episode 1049 finished after 8 steps
# Episode 1050 finished after 7 steps
# Episode 1051 finished after 5 steps
# Episode 1052 finished after 3 steps
# Episode 1053 finished after 4 steps
# Episode 1054 finished after 11 steps
# Episode 1055 finished after 2 steps
# Episode 1056 finished after 16 steps
# Episode 1057 finished after 8 steps
# Episode 1058 finished after 7 steps
# Episode 1059 finished after 9 steps
# Episode 1060 finished after 9 steps
# Episode 1061 finished after 2 steps
# Episode 1062 finished after 2 steps
# Episode 1063 finished after 14 steps
# Episode 1064 finished after 3 steps
# Episode 1065 finished after 12 steps
# Episode 1066 finished after 7 steps
# Episode 1067 finished after 5 steps
# Episode 1068 finished after 8 steps
# Episode 1069 finished after 11 steps
# Episode 1070 finished after 19 steps
# Episode 1071 finished after 3 steps
# Episode 1072 finished after 11 steps
# Episode 1073 finished after 2 steps
# Episode 1074 finished after 10 steps
# Episode 1075 finished after 3 steps
# Episode 1076 finished after 18 steps
# Episode 1077 finished after 3 steps
# Episode 1078 finished after 3 steps
# Episode 1079 finished after 9 steps
# Episode 1080 finished after 3 steps
# Episode 1081 finished after 6 steps
# Episode 1082 finished after 12 steps
# Episode 1083 finished after 11 steps
# Episode 1084 finished after 2 steps
# Episode 1085 finished after 2 steps
# Episode 1086 finished after 13 steps
# Episode 1087 finished after 4 steps
# Episode 1088 finished after 5 steps
# Episode 1089 finished after 3 steps
# Episode 1090 finished after 12 steps
# Episode 1091 finished after 4 steps
# Episode 1092 finished after 9 steps
# Episode 1093 finished after 4 steps
# Episode 1094 finished after 6 steps
# Episode 1095 finished after 11 steps
# Episode 1096 finished after 3 steps
# Episode 1097 finished after 9 steps
# Episode 1098 finished after 29 steps
# Episode 1099 finished after 11 steps
# Episode 1100 finished after 7 steps
# Episode 1101 finished after 30 steps
# Episode 1102 finished after 12 steps
# Episode 1103 finished after 15 steps
# Episode 1104 finished after 6 steps
# Episode 1105 finished after 3 steps
# Episode 1106 finished after 4 steps
# Episode 1107 finished after 3 steps
# Episode 1108 finished after 3 steps
# Episode 1109 finished after 2 steps
# Episode 1110 finished after 8 steps
# Episode 1111 finished after 5 steps
# Episode 1112 finished after 6 steps
# Episode 1113 finished after 2 steps
# Episode 1114 finished after 5 steps
# Episode 1115 finished after 2 steps
# Episode 1116 finished after 7 steps
# Episode 1117 finished after 10 steps
# Episode 1118 finished after 6 steps
# Episode 1119 finished after 9 steps
# Episode 1120 finished after 3 steps
# Episode 1121 finished after 30 steps
# Episode 1122 finished after 3 steps
# Episode 1123 finished after 18 steps
# Episode 1124 finished after 8 steps
# Episode 1125 finished after 10 steps
# Episode 1126 finished after 2 steps
# Episode 1127 finished after 4 steps
# Episode 1128 finished after 3 steps
# Episode 1129 finished after 3 steps
# Episode 1130 finished after 10 steps
# Episode 1131 finished after 3 steps
# Episode 1132 finished after 3 steps
# Episode 1133 finished after 9 steps
# Episode 1134 finished after 5 steps
# Episode 1135 finished after 8 steps
# Episode 1136 finished after 10 steps
# Episode 1137 finished after 9 steps
# Episode 1138 finished after 3 steps
# Episode 1139 finished after 11 steps
# Episode 1140 finished after 13 steps
# Episode 1141 finished after 9 steps
# Episode 1142 finished after 2 steps
# Episode 1143 finished after 2 steps
# Episode 1144 finished after 4 steps
# Episode 1145 finished after 6 steps
# Episode 1146 finished after 7 steps
# Episode 1147 finished after 8 steps
# Episode 1148 finished after 3 steps
# Episode 1149 finished after 12 steps
# Episode 1150 finished after 9 steps
# Episode 1151 finished after 13 steps
# Episode 1152 finished after 15 steps
# Episode 1153 finished after 2 steps
# Episode 1154 finished after 2 steps
# Episode 1155 finished after 7 steps
# Episode 1156 finished after 3 steps
# Episode 1157 finished after 12 steps
# Episode 1158 finished after 9 steps
# Episode 1159 finished after 4 steps
# Episode 1160 finished after 4 steps
# Episode 1161 finished after 7 steps
# Episode 1162 finished after 15 steps
# Episode 1163 finished after 10 steps
# Episode 1164 finished after 16 steps
# Episode 1165 finished after 4 steps
# Episode 1166 finished after 6 steps
# Episode 1167 finished after 6 steps
# Episode 1168 finished after 5 steps
# Episode 1169 finished after 5 steps
# Episode 1170 finished after 8 steps
# Episode 1171 finished after 10 steps
# Episode 1172 finished after 6 steps
# Episode 1173 finished after 4 steps
# Episode 1174 finished after 4 steps
# Episode 1175 finished after 5 steps
# Episode 1176 finished after 3 steps
# Episode 1177 finished after 21 steps
# Episode 1178 finished after 33 steps
# Episode 1179 finished after 2 steps
# Episode 1180 finished after 3 steps
# Episode 1181 finished after 3 steps
# Episode 1182 finished after 2 steps
# Episode 1183 finished after 2 steps
# Episode 1184 finished after 8 steps
# Episode 1185 finished after 7 steps
# Episode 1186 finished after 7 steps
# Episode 1187 finished after 6 steps
# Episode 1188 finished after 3 steps
# Episode 1189 finished after 13 steps
# Episode 1190 finished after 8 steps
# Episode 1191 finished after 2 steps
# Episode 1192 finished after 11 steps
# Episode 1193 finished after 7 steps
# Episode 1194 finished after 12 steps
# Episode 1195 finished after 5 steps
# Episode 1196 finished after 9 steps
# Episode 1197 finished after 6 steps
# Episode 1198 finished after 4 steps
# Episode 1199 finished after 9 steps
# Episode 1200 finished after 2 steps
# Episode 1201 finished after 2 steps
# Episode 1202 finished after 7 steps
# Episode 1203 finished after 10 steps
# Episode 1204 finished after 5 steps
# Episode 1205 finished after 5 steps
# Episode 1206 finished after 4 steps
# Episode 1207 finished after 9 steps
# Episode 1208 finished after 6 steps
# Episode 1209 finished after 3 steps
# Episode 1210 finished after 6 steps
# Episode 1211 finished after 12 steps
# Episode 1212 finished after 5 steps
# Episode 1213 finished after 2 steps
# Episode 1214 finished after 5 steps
# Episode 1215 finished after 8 steps
# Episode 1216 finished after 2 steps
# Episode 1217 finished after 3 steps
# Episode 1218 finished after 7 steps
# Episode 1219 finished after 4 steps
# Episode 1220 finished after 19 steps
# Episode 1221 finished after 2 steps
# Episode 1222 finished after 11 steps
# Episode 1223 finished after 3 steps
# Episode 1224 finished after 4 steps
# Episode 1225 finished after 10 steps
# Episode 1226 finished after 5 steps
# Episode 1227 finished after 2 steps
# Episode 1228 finished after 14 steps
# Episode 1229 finished after 8 steps
# Episode 1230 finished after 3 steps
# Episode 1231 finished after 7 steps
# Episode 1232 finished after 2 steps
# Episode 1233 finished after 10 steps
# Episode 1234 finished after 4 steps
# Episode 1235 finished after 5 steps
# Episode 1236 finished after 14 steps
# Episode 1237 finished after 7 steps
# Episode 1238 finished after 2 steps
# Episode 1239 finished after 17 steps
# Episode 1240 finished after 3 steps
# Episode 1241 finished after 13 steps
# Episode 1242 finished after 12 steps
# Episode 1243 finished after 11 steps
# Episode 1244 finished after 2 steps
# Episode 1245 finished after 2 steps
# Episode 1246 finished after 4 steps
# Episode 1247 finished after 8 steps
# Episode 1248 finished after 7 steps
# Episode 1249 finished after 11 steps
# Episode 1250 finished after 2 steps
# Episode 1251 finished after 7 steps
# Episode 1252 finished after 11 steps
# Episode 1253 finished after 3 steps
# Episode 1254 finished after 3 steps
# Episode 1255 finished after 3 steps
# Episode 1256 finished after 4 steps
# Episode 1257 finished after 10 steps
# Episode 1258 finished after 3 steps
# Episode 1259 finished after 7 steps
# Episode 1260 finished after 2 steps
# Episode 1261 finished after 11 steps
# Episode 1262 finished after 17 steps
# Episode 1263 finished after 3 steps
# Episode 1264 finished after 2 steps
# Episode 1265 finished after 7 steps
# Episode 1266 finished after 7 steps
# Episode 1267 finished after 4 steps
# Episode 1268 finished after 6 steps
# Episode 1269 finished after 9 steps
# Episode 1270 finished after 2 steps
# Episode 1271 finished after 4 steps
# Episode 1272 finished after 8 steps
# Episode 1273 finished after 5 steps
# Episode 1274 finished after 2 steps
# Episode 1275 finished after 2 steps
# Episode 1276 finished after 12 steps
# Episode 1277 finished after 4 steps
# Episode 1278 finished after 3 steps
# Episode 1279 finished after 8 steps
# Episode 1280 finished after 6 steps
# Episode 1281 finished after 5 steps
# Episode 1282 finished after 2 steps
# Episode 1283 finished after 3 steps
# Episode 1284 finished after 7 steps
# Episode 1285 finished after 7 steps
# Episode 1286 finished after 4 steps
# Episode 1287 finished after 6 steps
# Episode 1288 finished after 2 steps
# Episode 1289 finished after 8 steps
# Episode 1290 finished after 2 steps
# Episode 1291 finished after 8 steps
# Episode 1292 finished after 2 steps
# Episode 1293 finished after 7 steps
# Episode 1294 finished after 19 steps
# Episode 1295 finished after 7 steps
# Episode 1296 finished after 19 steps
# Episode 1297 finished after 9 steps
# Episode 1298 finished after 7 steps
# Episode 1299 finished after 2 steps
# Episode 1300 finished after 11 steps
# Episode 1301 finished after 2 steps
# Episode 1302 finished after 4 steps
# Episode 1303 finished after 3 steps
# Episode 1304 finished after 6 steps
# Episode 1305 finished after 24 steps
# Episode 1306 finished after 17 steps
# Episode 1307 finished after 10 steps
# Episode 1308 finished after 6 steps
# Episode 1309 finished after 3 steps
# Episode 1310 finished after 7 steps
# Episode 1311 finished after 6 steps
# Episode 1312 finished after 6 steps
# Episode 1313 finished after 7 steps
# Episode 1314 finished after 7 steps
# Episode 1315 finished after 9 steps
# Episode 1316 finished after 13 steps
# Episode 1317 finished after 4 steps
# Episode 1318 finished after 7 steps
# Episode 1319 finished after 16 steps
# Episode 1320 finished after 3 steps
# Episode 1321 finished after 14 steps
# Episode 1322 finished after 3 steps
# Episode 1323 finished after 5 steps
# Episode 1324 finished after 3 steps
# Episode 1325 finished after 15 steps
# Episode 1326 finished after 2 steps
# Episode 1327 finished after 2 steps
# Episode 1328 finished after 2 steps
# Episode 1329 finished after 11 steps
# Episode 1330 finished after 15 steps
# Episode 1331 finished after 5 steps
# Episode 1332 finished after 18 steps
# Episode 1333 finished after 30 steps
# Episode 1334 finished after 6 steps
# Episode 1335 finished after 9 steps
# Episode 1336 finished after 4 steps
# Episode 1337 finished after 4 steps
# Episode 1338 finished after 15 steps
# Episode 1339 finished after 8 steps
# Episode 1340 finished after 12 steps
# Episode 1341 finished after 8 steps
# Episode 1342 finished after 14 steps
# Episode 1343 finished after 2 steps
# Episode 1344 finished after 2 steps
# Episode 1345 finished after 14 steps
# Episode 1346 finished after 9 steps
# Episode 1347 finished after 12 steps
# Episode 1348 finished after 2 steps
# Episode 1349 finished after 6 steps
# Episode 1350 finished after 7 steps
# Episode 1351 finished after 4 steps
# Episode 1352 finished after 6 steps
# Episode 1353 finished after 12 steps
# ...
# Episode 9008 finished after 7 steps
# Episode 9009 finished after 11 steps
# Episode 9010 finished after 6 steps
# Episode 9011 finished after 13 steps
# Episode 9012 finished after 8 steps
# Episode 9013 finished after 2 steps
# Episode 9014 finished after 2 steps
# Episode 9015 finished after 2 steps
# Episode 9016 finished after 5 steps
# Episode 9017 finished after 13 steps
# Episode 9018 finished after 2 steps
# Episode 9019 finished after 27 steps
# Episode 9020 finished after 7 steps
# Episode 9021 finished after 2 steps
# Episode 9022 finished after 4 steps
# Episode 9023 finished after 4 steps
# Episode 9024 finished after 4 steps
# Episode 9025 finished after 9 steps
# Episode 9026 finished after 2 steps
# Episode 9027 finished after 3 steps
# Episode 9028 finished after 8 steps
# Episode 9029 finished after 6 steps
# Episode 9030 finished after 8 steps
# Episode 9031 finished after 3 steps
# Episode 9032 finished after 2 steps
# Episode 9033 finished after 4 steps
# Episode 9034 finished after 5 steps
# Episode 9035 finished after 5 steps
# Episode 9036 finished after 3 steps
# Episode 9037 finished after 5 steps
# Episode 9038 finished after 2 steps
# Episode 9039 finished after 5 steps
# Episode 9040 finished after 9 steps
# Episode 9041 finished after 5 steps
# Episode 9042 finished after 3 steps
# Episode 9043 finished after 10 steps
# Episode 9044 finished after 7 steps
# Episode 9045 finished after 4 steps
# Episode 9046 finished after 4 steps
# Episode 9047 finished after 3 steps
# Episode 9048 finished after 3 steps
# Episode 9049 finished after 13 steps
# Episode 9050 finished after 6 steps
# Episode 9051 finished after 8 steps
# Episode 9052 finished after 3 steps
# Episode 9053 finished after 11 steps
# Episode 9054 finished after 18 steps
# Episode 9055 finished after 6 steps
# Episode 9056 finished after 4 steps
# Episode 9057 finished after 3 steps
# Episode 9058 finished after 8 steps
# Episode 9059 finished after 5 steps
# Episode 9060 finished after 9 steps
# Episode 9061 finished after 14 steps
# Episode 9062 finished after 9 steps
# Episode 9063 finished after 8 steps
# Episode 9064 finished after 7 steps
# Episode 9065 finished after 7 steps
# Episode 9066 finished after 13 steps
# Episode 9067 finished after 15 steps
# Episode 9068 finished after 9 steps
# Episode 9069 finished after 2 steps
# Episode 9070 finished after 6 steps
# Episode 9071 finished after 4 steps
# Episode 9072 finished after 10 steps
# Episode 9073 finished after 16 steps
# Episode 9074 finished after 2 steps
# Episode 9075 finished after 8 steps
# Episode 9076 finished after 9 steps
# Episode 9077 finished after 6 steps
# Episode 9078 finished after 8 steps
# Episode 9079 finished after 3 steps
# Episode 9080 finished after 3 steps
# Episode 9081 finished after 10 steps
# Episode 9082 finished after 12 steps
# Episode 9083 finished after 13 steps
# Episode 9084 finished after 6 steps
# Episode 9085 finished after 16 steps
# Episode 9086 finished after 11 steps
# Episode 9087 finished after 6 steps
# Episode 9088 finished after 5 steps
# Episode 9089 finished after 19 steps
# Episode 9090 finished after 4 steps
# Episode 9091 finished after 17 steps
# Episode 9092 finished after 3 steps
# Episode 9093 finished after 18 steps
# Episode 9094 finished after 7 steps
# Episode 9095 finished after 3 steps
# Episode 9096 finished after 7 steps
# Episode 9097 finished after 11 steps
# Episode 9098 finished after 3 steps
# Episode 9099 finished after 5 steps
# Episode 9100 finished after 15 steps
# Episode 9101 finished after 19 steps
# Episode 9102 finished after 2 steps
# Episode 9103 finished after 4 steps
# Episode 9104 finished after 8 steps
# Episode 9105 finished after 10 steps
# Episode 9106 finished after 2 steps
# Episode 9107 finished after 14 steps
# Episode 9108 finished after 20 steps
# Episode 9109 finished after 9 steps
# Episode 9110 finished after 3 steps
# Episode 9111 finished after 6 steps
# Episode 9112 finished after 6 steps
# Episode 9113 finished after 3 steps
# Episode 9114 finished after 8 steps
# Episode 9115 finished after 14 steps
# Episode 9116 finished after 14 steps
# Episode 9117 finished after 3 steps
# Episode 9118 finished after 2 steps
# Episode 9119 finished after 6 steps
# Episode 9120 finished after 5 steps
# Episode 9121 finished after 14 steps
# Episode 9122 finished after 9 steps
# Episode 9123 finished after 8 steps
# Episode 9124 finished after 2 steps
# Episode 9125 finished after 7 steps
# Episode 9126 finished after 7 steps
# Episode 9127 finished after 13 steps
# Episode 9128 finished after 5 steps
# Episode 9129 finished after 3 steps
# Episode 9130 finished after 3 steps
# Episode 9131 finished after 12 steps
# Episode 9132 finished after 8 steps
# Episode 9133 finished after 9 steps
# Episode 9134 finished after 5 steps
# Episode 9135 finished after 7 steps
# Episode 9136 finished after 5 steps
# Episode 9137 finished after 6 steps
# Episode 9138 finished after 8 steps
# Episode 9139 finished after 10 steps
# Episode 9140 finished after 8 steps
# Episode 9141 finished after 7 steps
# Episode 9142 finished after 5 steps
# Episode 9143 finished after 12 steps
# Episode 9144 finished after 3 steps
# Episode 9145 finished after 2 steps
# Episode 9146 finished after 18 steps
# Episode 9147 finished after 2 steps
# Episode 9148 finished after 9 steps
# Episode 9149 finished after 14 steps
# Episode 9150 finished after 2 steps
# Episode 9151 finished after 2 steps
# Episode 9152 finished after 22 steps
# Episode 9153 finished after 5 steps
# Episode 9154 finished after 2 steps
# Episode 9155 finished after 12 steps
# Episode 9156 finished after 4 steps
# Episode 9157 finished after 4 steps
# Episode 9158 finished after 4 steps
# Episode 9159 finished after 6 steps
# Episode 9160 finished after 2 steps
# Episode 9161 finished after 12 steps
# Episode 9162 finished after 4 steps
# Episode 9163 finished after 5 steps
# Episode 9164 finished after 8 steps
# Episode 9165 finished after 9 steps
# Episode 9166 finished after 10 steps
# Episode 9167 finished after 2 steps
# Episode 9168 finished after 4 steps
# Episode 9169 finished after 5 steps
# Episode 9170 finished after 8 steps
# Episode 9171 finished after 13 steps
# Episode 9172 finished after 13 steps
# Episode 9173 finished after 3 steps
# Episode 9174 finished after 8 steps
# Episode 9175 finished after 17 steps
# Episode 9176 finished after 17 steps
# Episode 9177 finished after 3 steps
# Episode 9178 finished after 17 steps
# Episode 9179 finished after 5 steps
# Episode 9180 finished after 18 steps
# Episode 9181 finished after 10 steps
# Episode 9182 finished after 7 steps
# Episode 9183 finished after 20 steps
# Episode 9184 finished after 9 steps
# Episode 9185 finished after 3 steps
# Episode 9186 finished after 3 steps
# Episode 9187 finished after 11 steps
# Episode 9188 finished after 5 steps
# Episode 9189 finished after 8 steps
# Episode 9190 finished after 2 steps
# Episode 9191 finished after 9 steps
# Episode 9192 finished after 2 steps
# Episode 9193 finished after 3 steps
# Episode 9194 finished after 6 steps
# Episode 9195 finished after 2 steps
# Episode 9196 finished after 14 steps
# Episode 9197 finished after 2 steps
# Episode 9198 finished after 3 steps
# Episode 9199 finished after 5 steps
# Episode 9200 finished after 8 steps
# Episode 9201 finished after 8 steps
# Episode 9202 finished after 14 steps
# Episode 9203 finished after 10 steps
# Episode 9204 finished after 6 steps
# Episode 9205 finished after 10 steps
# Episode 9206 finished after 8 steps
# Episode 9207 finished after 9 steps
# Episode 9208 finished after 4 steps
# Episode 9209 finished after 5 steps
# Episode 9210 finished after 7 steps
# Episode 9211 finished after 2 steps
# Episode 9212 finished after 19 steps
# Episode 9213 finished after 16 steps
# Episode 9214 finished after 4 steps
# Episode 9215 finished after 7 steps
# Episode 9216 finished after 5 steps
# Episode 9217 finished after 10 steps
# Episode 9218 finished after 12 steps
# Episode 9219 finished after 4 steps
# Episode 9220 finished after 2 steps
# Episode 9221 finished after 5 steps
# Episode 9222 finished after 7 steps
# Episode 9223 finished after 3 steps
# Episode 9224 finished after 8 steps
# Episode 9225 finished after 3 steps
# Episode 9226 finished after 3 steps
# Episode 9227 finished after 13 steps
# Episode 9228 finished after 6 steps
# Episode 9229 finished after 5 steps
# Episode 9230 finished after 12 steps
# Episode 9231 finished after 5 steps
# Episode 9232 finished after 4 steps
# Episode 9233 finished after 10 steps
# Episode 9234 finished after 10 steps
# Episode 9235 finished after 3 steps
# Episode 9236 finished after 8 steps
# Episode 9237 finished after 18 steps
# Episode 9238 finished after 17 steps
# Episode 9239 finished after 5 steps
# Episode 9240 finished after 9 steps
# Episode 9241 finished after 13 steps
# Episode 9242 finished after 7 steps
# Episode 9243 finished after 9 steps
# Episode 9244 finished after 6 steps
# Episode 9245 finished after 6 steps
# Episode 9246 finished after 13 steps
# Episode 9247 finished after 9 steps
# Episode 9248 finished after 8 steps
# Episode 9249 finished after 9 steps
# Episode 9250 finished after 6 steps
# Episode 9251 finished after 2 steps
# Episode 9252 finished after 2 steps
# Episode 9253 finished after 4 steps
# Episode 9254 finished after 8 steps
# Episode 9255 finished after 3 steps
# Episode 9256 finished after 5 steps
# Episode 9257 finished after 6 steps
# Episode 9258 finished after 4 steps
# Episode 9259 finished after 3 steps
# Episode 9260 finished after 2 steps
# Episode 9261 finished after 7 steps
# Episode 9262 finished after 3 steps
# Episode 9263 finished after 4 steps
# Episode 9264 finished after 4 steps
# Episode 9265 finished after 3 steps
# Episode 9266 finished after 13 steps
# Episode 9267 finished after 5 steps
# Episode 9268 finished after 12 steps
# Episode 9269 finished after 3 steps
# Episode 9270 finished after 6 steps
# Episode 9271 finished after 3 steps
# Episode 9272 finished after 10 steps
# Episode 9273 finished after 11 steps
# Episode 9274 finished after 2 steps
# Episode 9275 finished after 8 steps
# Episode 9276 finished after 6 steps
# Episode 9277 finished after 8 steps
# Episode 9278 finished after 8 steps
# Episode 9279 finished after 6 steps
# Episode 9280 finished after 8 steps
# Episode 9281 finished after 8 steps
# Episode 9282 finished after 8 steps
# Episode 9283 finished after 5 steps
# Episode 9284 finished after 3 steps
# Episode 9285 finished after 8 steps
# Episode 9286 finished after 10 steps
# Episode 9287 finished after 5 steps
# Episode 9288 finished after 2 steps
# Episode 9289 finished after 12 steps
# Episode 9290 finished after 7 steps
# Episode 9291 finished after 3 steps
# Episode 9292 finished after 2 steps
# Episode 9293 finished after 3 steps
# Episode 9294 finished after 9 steps
# Episode 9295 finished after 3 steps
# Episode 9296 finished after 5 steps
# Episode 9297 finished after 7 steps
# Episode 9298 finished after 23 steps
# Episode 9299 finished after 21 steps
# Episode 9300 finished after 2 steps
# Episode 9301 finished after 5 steps
# Episode 9302 finished after 2 steps
# Episode 9303 finished after 3 steps
# Episode 9304 finished after 2 steps
# Episode 9305 finished after 2 steps
# Episode 9306 finished after 9 steps
# Episode 9307 finished after 7 steps
# Episode 9308 finished after 14 steps
# Episode 9309 finished after 4 steps
# Episode 9310 finished after 4 steps
# Episode 9311 finished after 3 steps
# Episode 9312 finished after 7 steps
# Episode 9313 finished after 5 steps
# Episode 9314 finished after 8 steps
# Episode 9315 finished after 31 steps
# Episode 9316 finished after 21 steps
# Episode 9317 finished after 3 steps
# Episode 9318 finished after 2 steps
# Episode 9319 finished after 13 steps
# Episode 9320 finished after 27 steps
# Episode 9321 finished after 19 steps
# Episode 9322 finished after 4 steps
# Episode 9323 finished after 10 steps
# Episode 9324 finished after 9 steps
# Episode 9325 finished after 5 steps
# Episode 9326 finished after 4 steps
# Episode 9327 finished after 2 steps
# Episode 9328 finished after 12 steps
# Episode 9329 finished after 9 steps
# Episode 9330 finished after 7 steps
# Episode 9331 finished after 5 steps
# Episode 9332 finished after 8 steps
# Episode 9333 finished after 5 steps
# Episode 9334 finished after 3 steps
# Episode 9335 finished after 5 steps
# Episode 9336 finished after 14 steps
# Episode 9337 finished after 18 steps
# Episode 9338 finished after 5 steps
# Episode 9339 finished after 2 steps
# Episode 9340 finished after 19 steps
# Episode 9341 finished after 4 steps
# Episode 9342 finished after 2 steps
# Episode 9343 finished after 2 steps
# Episode 9344 finished after 5 steps
# Episode 9345 finished after 6 steps
# Episode 9346 finished after 4 steps
# Episode 9347 finished after 12 steps
# Episode 9348 finished after 25 steps
# Episode 9349 finished after 9 steps
# Episode 9350 finished after 3 steps
# Episode 9351 finished after 11 steps
# Episode 9352 finished after 4 steps
# Episode 9353 finished after 10 steps
# Episode 9354 finished after 6 steps
# Episode 9355 finished after 9 steps
# Episode 9356 finished after 2 steps
# Episode 9357 finished after 7 steps
# Episode 9358 finished after 4 steps
# Episode 9359 finished after 14 steps
# Episode 9360 finished after 9 steps
# Episode 9361 finished after 2 steps
# Episode 9362 finished after 2 steps
# Episode 9363 finished after 7 steps
# Episode 9364 finished after 17 steps
# Episode 9365 finished after 10 steps
# Episode 9366 finished after 10 steps
# Episode 9367 finished after 5 steps
# Episode 9368 finished after 18 steps
# Episode 9369 finished after 2 steps
# Episode 9370 finished after 3 steps
# Episode 9371 finished after 18 steps
# Episode 9372 finished after 2 steps
# Episode 9373 finished after 14 steps
# Episode 9374 finished after 14 steps
# Episode 9375 finished after 3 steps
# Episode 9376 finished after 3 steps
# Episode 9377 finished after 13 steps
# Episode 9378 finished after 6 steps
# Episode 9379 finished after 7 steps
# Episode 9380 finished after 2 steps
# Episode 9381 finished after 3 steps
# Episode 9382 finished after 8 steps
# Episode 9383 finished after 8 steps
# Episode 9384 finished after 9 steps
# Episode 9385 finished after 5 steps
# Episode 9386 finished after 9 steps
# Episode 9387 finished after 4 steps
# Episode 9388 finished after 4 steps
# Episode 9389 finished after 4 steps
# Episode 9390 finished after 7 steps
# Episode 9391 finished after 3 steps
# Episode 9392 finished after 6 steps
# Episode 9393 finished after 4 steps
# Episode 9394 finished after 9 steps
# Episode 9395 finished after 4 steps
# Episode 9396 finished after 10 steps
# Episode 9397 finished after 3 steps
# Episode 9398 finished after 6 steps
# Episode 9399 finished after 6 steps
# Episode 9400 finished after 4 steps
# Episode 9401 finished after 3 steps
# Episode 9402 finished after 8 steps
# Episode 9403 finished after 16 steps
# Episode 9404 finished after 6 steps
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 best_hyperparameters, best_performance, results_df = hyperparameter_search()
#       2 print("Best Hyperparameters:", best_hyperparameters)
#       3 print("Best Average Steps to Goal:", best_performance)
#
# Cell In[59], line 83, in hyperparameter_search()
#      81 for gamma in discount_factors:
#      82     for decay in epsilon_decays:
# ---> 83         avg_steps, q_table ,steps_per_episode,is_success = train_agent(env, alpha, gamma, decay)
#      84         print(f"Alpha: {alpha}, Gamma: {gamma}, Decay: {decay}, Avg Steps: {avg_steps} Success: {is_success}")
#      86         results_dict['alpha'].append(alpha)
#
# Cell In[59], line 61, in train_agent(env, alpha, gamma, epsilon_decay, num_episodes)
#      59     print(f"Episode {episode} finished after {steps} steps")
#      60     steps_per_episode.append(steps)
# ---> 61     is_success = check_success_condition(steps_per_episode)
#      62 avg_steps = np.mean(steps_per_episode[-100:])  # Average steps of the last 100 episodes
#      63 return avg_steps, q_table, steps_per_episode, is_success
#
# Cell In[59], line 28, in check_success_condition(steps_per_episode, consecutive_episodes, threshold)
#      26 steps_per_episode = np.array(steps_per_episode)
#      27 for i in range(len(steps_per_episode) - consecutive_episodes):
# ---> 28     if all(steps_per_episode[i:i+consecutive_episodes] >= threshold):
#      29         return True
#      30 return False
#
# KeyboardInterrupt:

# %%
results_df.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_3270a_row0_col0, #T_3270a_row0_col1, #T_3270a_row0_col2, #T_3270a_row1_col0, #T_3270a_row1_col1, #T_3270a_row2_col0, #T_3270a_row2_col1, #T_3270a_row3_col0, #T_3270a_row3_col2, #T_3270a_row4_col0, #T_3270a_row5_col0, #T_3270a_row6_col0, #T_3270a_row6_col2, #T_3270a_row7_col0, #T_3270a_row8_col0, #T_3270a_row9_col1, #T_3270a_row9_col2, #T_3270a_row10_col1, #T_3270a_row11_col1, #T_3270a_row12_col2, #T_3270a_row15_col2, #T_3270a_row16_col3, #T_3270a_row18_col1, #T_3270a_row18_col2, #T_3270a_row19_col1, #T_3270a_row20_col1, #T_3270a_row21_col2, #T_3270a_row24_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_3270a_row0_col3 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_3270a_row1_col2, #T_3270a_row4_col2, #T_3270a_row7_col2, #T_3270a_row10_col2, #T_3270a_row13_col2, #T_3270a_row16_col2, #T_3270a_row19_col2, #T_3270a_row22_col2, #T_3270a_row25_col2 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_3270a_row1_col3 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_3270a_row2_col2, #T_3270a_row5_col2, #T_3270a_row6_col1, #T_3270a_row7_col1, #T_3270a_row8_col1, #T_3270a_row8_col2, #T_3270a_row11_col2, #T_3270a_row14_col2, #T_3270a_row15_col1, #T_3270a_row16_col1, #T_3270a_row17_col1, #T_3270a_row17_col2, #T_3270a_row18_col0, #T_3270a_row19_col0, #T_3270a_row20_col0, #T_3270a_row20_col2, #T_3270a_row21_col0, #T_3270a_row21_col3, #T_3270a_row22_col0, #T_3270a_row23_col0, #T_3270a_row23_col2, #T_3270a_row24_col0, #T_3270a_row24_col1, #T_3270a_row25_col0, #T_3270a_row25_col1, #T_3270a_row26_col0, #T_3270a_row26_col1, #T_3270a_row26_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3270a_row2_col3 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_3270a_row3_col1, #T_3270a_row4_col1, #T_3270a_row5_col1, #T_3270a_row12_col1, #T_3270a_row13_col1, #T_3270a_row14_col1, #T_3270a_row21_col1, #T_3270a_row22_col1, #T_3270a_row23_col1 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_3270a_row3_col3 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_3270a_row4_col3 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_3270a_row5_col3 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_3270a_row6_col3 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_3270a_row7_col3 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_3270a_row8_col3 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_3270a_row9_col0, #T_3270a_row10_col0, #T_3270a_row11_col0, #T_3270a_row12_col0, #T_3270a_row13_col0, #T_3270a_row14_col0, #T_3270a_row15_col0, #T_3270a_row16_col0, #T_3270a_row17_col0 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_3270a_row9_col3 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_3270a_row10_col3 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_3270a_row11_col3 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_3270a_row12_col3 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_3270a_row13_col3 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_3270a_row14_col3, #T_3270a_row22_col3 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_3270a_row15_col3 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_3270a_row17_col3 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_3270a_row18_col3 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_3270a_row19_col3, #T_3270a_row24_col3 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_3270a_row20_col3 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_3270a_row23_col3 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_3270a_row25_col3 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_3270a_row26_col3 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3270a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3270a_level0_col0" class="col_heading level0 col0" >alpha</th>
#       <th id="T_3270a_level0_col1" class="col_heading level0 col1" >gamma</th>
#       <th id="T_3270a_level0_col2" class="col_heading level0 col2" >epsilon_decay</th>
#       <th id="T_3270a_level0_col3" class="col_heading level0 col3" >avg_steps</th>
#       <th id="T_3270a_level0_col4" class="col_heading level0 col4" >success</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3270a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3270a_row0_col0" class="data row0 col0" >0.500000</td>
#       <td id="T_3270a_row0_col1" class="data row0 col1" >0.800000</td>
#       <td id="T_3270a_row0_col2" class="data row0 col2" >0.001000</td>
#       <td id="T_3270a_row0_col3" class="data row0 col3" >6.760000</td>
#       <td id="T_3270a_row0_col4" class="data row0 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3270a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3270a_row1_col0" class="data row1 col0" >0.500000</td>
#       <td id="T_3270a_row1_col1" class="data row1 col1" >0.800000</td>
#       <td id="T_3270a_row1_col2" class="data row1 col2" >0.005000</td>
#       <td id="T_3270a_row1_col3" class="data row1 col3" >7.040000</td>
#       <td id="T_3270a_row1_col4" class="data row1 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3270a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3270a_row2_col0" class="data row2 col0" >0.500000</td>
#       <td id="T_3270a_row2_col1" class="data row2 col1" >0.800000</td>
#       <td id="T_3270a_row2_col2" class="data row2 col2" >0.010000</td>
#       <td id="T_3270a_row2_col3" class="data row2 col3" >7.940000</td>
#       <td id="T_3270a_row2_col4" class="data row2 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3270a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3270a_row3_col0" class="data row3 col0" >0.500000</td>
#       <td id="T_3270a_row3_col1" class="data row3 col1" >0.900000</td>
#       <td id="T_3270a_row3_col2" class="data row3 col2" >0.001000</td>
#       <td id="T_3270a_row3_col3" class="data row3 col3" >7.010000</td>
#       <td id="T_3270a_row3_col4" class="data row3 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3270a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3270a_row4_col0" class="data row4 col0" >0.500000</td>
#       <td id="T_3270a_row4_col1" class="data row4 col1" >0.900000</td>
#       <td id="T_3270a_row4_col2" class="data row4 col2" >0.005000</td>
#       <td id="T_3270a_row4_col3" class="data row4 col3" >8.130000</td>
#       <td id="T_3270a_row4_col4" class="data row4 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3270a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3270a_row5_col0" class="data row5 col0" >0.500000</td>
#       <td id="T_3270a_row5_col1" class="data row5 col1" >0.900000</td>
#       <td id="T_3270a_row5_col2" class="data row5 col2" >0.010000</td>
#       <td id="T_3270a_row5_col3" class="data row5 col3" >7.560000</td>
#       <td id="T_3270a_row5_col4" class="data row5 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3270a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3270a_row6_col0" class="data row6 col0" >0.500000</td>
#       <td id="T_3270a_row6_col1" class="data row6 col1" >0.990000</td>
#       <td id="T_3270a_row6_col2" class="data row6 col2" >0.001000</td>
#       <td id="T_3270a_row6_col3" class="data row6 col3" >8.400000</td>
#       <td id="T_3270a_row6_col4" class="data row6 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3270a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3270a_row7_col0" class="data row7 col0" >0.500000</td>
#       <td id="T_3270a_row7_col1" class="data row7 col1" >0.990000</td>
#       <td id="T_3270a_row7_col2" class="data row7 col2" >0.005000</td>
#       <td id="T_3270a_row7_col3" class="data row7 col3" >8.530000</td>
#       <td id="T_3270a_row7_col4" class="data row7 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3270a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3270a_row8_col0" class="data row8 col0" >0.500000</td>
#       <td id="T_3270a_row8_col1" class="data row8 col1" >0.990000</td>
#       <td id="T_3270a_row8_co

# %%
# Initialize the FrozenLake environment
env = gym.make('FrozenLake-v1',is_slippery=True)

# Initialize Q-table with zeros for each state-action pair
q_table = np.zeros([env.observation_space.n, env.action_space.n])

# Hyperparameters
alpha = 0.8   # Learning rate
gamma = 0.3  # Discount factor
epsilon = 1.0   # Epsilon-greedy probability
num_episodes = 10000
# Decay rate as a function of number of episodes
decay_rate = 0.0002  # Decay rate for epsilon
batch_e_greedy = True
batch_size = 500
decay_rate = 0.1
# For stats
steps_per_episode = []
# Q-learning algorithm
for episode in range(num_episodes):
    state = env.reset()[0]
    done = False
    steps = 0
    while not done:

        # Epsilon-greedy action selection
        if np.random.uniform(0, 1) < epsilon:
            action = env.action_space.sample()  # Explore action space
        else:
            action = np.argmax(q_table[state])  # Exploit learned values
        steps +=1
        #Take action A and Observe R and S'
        next_state, reward, done, truncated,info = env.step(action)
        # Q-table update
        # Old value is Q(S,A)
        old_value = q_table[state, action]
        # Now that we are at state S' we can look at all possible actions and pick the best one
        next_max = np.max(q_table[next_state])
        # Updating Q(S,A) with the new value
        new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_max)
        q_table[state, action] = new_value
        
        state = next_state
    if episode % 500 == 0:
        print(f"epsilon at episode {episode}: {epsilon}")
    # print(f"Episode {episode} finished after {steps} steps")
    # Decaying epsilon
    steps_per_episode.append(steps)
    if batch_e_greedy:
        if episode % batch_size == 0:
            epsilon = epsilon - decay_rate if epsilon > 0 else 0
    else:
        epsilon = epsilon - decay_rate if epsilon > 0 else 0

print("Training finished.")
# Out:
# epsilon at episode 0: 1.0
# epsilon at episode 500: 0.9
# epsilon at episode 1000: 0.8
# epsilon at episode 1500: 0.7000000000000001
# epsilon at episode 2000: 0.6000000000000001
# epsilon at episode 2500: 0.5000000000000001
# epsilon at episode 3000: 0.40000000000000013
# epsilon at episode 3500: 0.30000000000000016
# epsilon at episode 4000: 0.20000000000000015
# epsilon at episode 4500: 0.10000000000000014
# epsilon at episode 5000: 1.3877787807814457e-16
# epsilon at episode 5500: -0.09999999999999987
# epsilon at episode 6000: 0
# epsilon at episode 6500: 0
# epsilon at episode 7000: 0
# epsilon at episode 7500: 0
# epsilon at episode 8000: 0
# epsilon at episode 8500: 0
# epsilon at episode 9000: 0
# epsilon at episode 9500: 0
# Training finished.

# %%
steps_per_episode = np.array(steps_per_episode)
plt.scatter(y=steps_per_episode,x=np.arange(len(steps_per_episode)),s=4,alpha=0.2)
plt.axhline(y=100, color='red', linestyle='--')
for i in range(0, len(steps_per_episode)+1, 5000):
    plt.axvline(x=i, color='orange', linestyle='--')
# Moving average
window = 100
step = 100
rolling_mean = pd.Series(steps_per_episode).rolling(window,step=step).mean()
plt.scatter(y=rolling_mean,x=np.arange(len(steps_per_episode),step=step),s=3,color='red')

# %%
plot_steps_per_episode(steps_per_episode)

# %%
# Assuming q_table is your trained Q-table
policy = extract_policy(q_table)
plot_policy(policy)
